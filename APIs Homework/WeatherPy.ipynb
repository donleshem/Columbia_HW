# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import random

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
citi_data = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={api_key}'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# 
citi_counter = 1
print("Beginning Data Retrieval")
print("-----------------------------")

ran_index = random.sample(cities,500)
for citi in ran_index:
    try:
        url = f'http://api.openweathermap.org/data/2.5/weather?q={citi}&APPID={api_key}'
        response = requests.get(url)
        #print(response)
        if response.status_code != 200:
            print('City not found. Skipping...')
        print("Processing Record " + str(citi_counter) +" of Set 1 |" + citi)
        citi_counter += 1
        weather_json = response.json()
        # Append the City information into city_data list
        citi_data.append({"City": citi, 
                          "Lat": weather_json['coord']['lat'], 
                          "Lng": weather_json['coord']['lon'], 
                          "Max Temp": weather_json['main']['temp_max'],
                          "Humidity": weather_json['main']['humidity'],
                          "Cloudiness": weather_json['clouds']['all'],
                          "Wind Speed": weather_json['wind']['speed'],
                          "Country": weather_json['sys']['country'],
                          "Date": weather_json['dt']})

    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 |mount isa
# Processing Record 2 of Set 1 |tarata
# Processing Record 3 of Set 1 |batavia
# Processing Record 4 of Set 1 |balabac
# Processing Record 5 of Set 1 |baykit
# Processing Record 6 of Set 1 |santa maria
# Processing Record 7 of Set 1 |mwense
# Processing Record 8 of Set 1 |gigmoto
# Processing Record 9 of Set 1 |mount darwin
# Processing Record 10 of Set 1 |barcelona
# Processing Record 11 of Set 1 |muros
# Processing Record 12 of Set 1 |kodiak
# Processing Record 13 of Set 1 |pasuruan
# Processing Record 14 of Set 1 |yulara
# Processing Record 15 of Set 1 |qaqortoq
# Processing Record 16 of Set 1 |baghdad
# Processing Record 17 of Set 1 |aksarka
# Processing Record 18 of Set 1 |leshukonskoye
# Processing Record 19 of Set 1 |katsuura
# Processing Record 20 of Set 1 |cabo san lucas
# Processing Record 21 of Set 1 |palmer
# Processing Record 22 of Set 1 |namibe
# Processing Record 23 of Set 1 |little current
# City not found. Skipping...
# Processing Record 24 of Set 1 |abomsa
# City not found. Skipping...
# Processing Record 25 of Set 1 |ha noi
# Processing Record 26 of Set 1 |pangai
# Processing Record 27 of Set 1 |san cristobal
# Processing Record 28 of Set 1 |hudson bay
# Processing Record 29 of Set 1 |burla
# Processing Record 30 of Set 1 |shubarkuduk
# Processing Record 31 of Set 1 |culfa
# Processing Record 32 of Set 1 |constitucion
# Processing Record 33 of Set 1 |saint-louis
# Processing Record 34 of Set 1 |kropotkin
# Processing Record 35 of Set 1 |nemuro
# Processing Record 36 of Set 1 |vavozh
# Processing Record 37 of Set 1 |meulaboh
# Processing Record 38 of Set 1 |manggar
# City not found. Skipping...
# Processing Record 39 of Set 1 |bargal
# City not found. Skipping...
# Processing Record 40 of Set 1 |mayfield
# Processing Record 41 of Set 1 |ulcinj
# Processing Record 42 of Set 1 |hobyo
# Processing Record 43 of Set 1 |saint-joseph
# Processing Record 44 of Set 1 |phitsanulok
# Processing Record 45 of Set 1 |sinnamary
# Processing Record 46 of Set 1 |paamiut
# Processing Record 47 of Set 1 |emerald
# Processing Record 48 of Set 1 |atambua
# Processing Record 49 of Set 1 |pemba
# City not found. Skipping...
# Processing Record 50 of Set 1 |skalistyy
# City not found. Skipping...
# Processing Record 51 of Set 1 |bethel
# Processing Record 52 of Set 1 |conde
# City not found. Skipping...
# Processing Record 53 of Set 1 |umzimvubu
# City not found. Skipping...
# Processing Record 54 of Set 1 |berlevag
# Processing Record 55 of Set 1 |steamboat springs
# Processing Record 56 of Set 1 |duncan
# Processing Record 57 of Set 1 |sobolevo
# Processing Record 58 of Set 1 |banepa
# Processing Record 59 of Set 1 |nanakuli
# City not found. Skipping...
# Processing Record 60 of Set 1 |wulanhaote
# City not found. Skipping...
# Processing Record 61 of Set 1 |husavik
# Processing Record 62 of Set 1 |flin flon
# Processing Record 63 of Set 1 |laramie
# Processing Record 64 of Set 1 |svetlogorsk
# Processing Record 65 of Set 1 |dourbali
# Processing Record 66 of Set 1 |isangel
# Processing Record 67 of Set 1 |erzin
# Processing Record 68 of Set 1 |batagay-alyta
# Processing Record 69 of Set 1 |saskylakh
# City not found. Skipping...
# Processing Record 70 of Set 1 |buariki
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 71 of Set 1 |barawe
# City not found. Skipping...
# Processing Record 72 of Set 1 |yamada
# Processing Record 73 of Set 1 |oksfjord
# Processing Record 74 of Set 1 |kabare
# Processing Record 75 of Set 1 |ambunti
# Processing Record 76 of Set 1 |bang saphan
# Processing Record 77 of Set 1 |vostok
# Processing Record 78 of Set 1 |cairns
# Processing Record 79 of Set 1 |fostoria
# Processing Record 80 of Set 1 |whitehorse
# Processing Record 81 of Set 1 |carnarvon
# City not found. Skipping...
# Processing Record 82 of Set 1 |asfi
# City not found. Skipping...
# Processing Record 83 of Set 1 |ossora
# Processing Record 84 of Set 1 |koping
# City not found. Skipping...
# Processing Record 85 of Set 1 |nizhneyansk
# City not found. Skipping...
# Processing Record 86 of Set 1 |zhigansk
# City not found. Skipping...
# Processing Record 87 of Set 1 |pemangkat
# City not found. Skipping...
# Processing Record 88 of Set 1 |coolum beach
# Processing Record 89 of Set 1 |grindavik
# Processing Record 90 of Set 1 |seoul
# Processing Record 91 of Set 1 |gaffney
# City not found. Skipping...
# Processing Record 92 of Set 1 |meyungs
# City not found. Skipping...
# Processing Record 93 of Set 1 |buala
# Processing Record 94 of Set 1 |sorland
# Processing Record 95 of Set 1 |alyangula
# Processing Record 96 of Set 1 |bethanien
# Processing Record 97 of Set 1 |kloulklubed
# Processing Record 98 of Set 1 |kavieng
# Processing Record 99 of Set 1 |srednekolymsk
# Processing Record 100 of Set 1 |tecolutla
# Processing Record 101 of Set 1 |saint anthony
# Processing Record 102 of Set 1 |bandarbeyla
# City not found. Skipping...
# Processing Record 103 of Set 1 |taburi
# City not found. Skipping...
# Processing Record 104 of Set 1 |pendleton
# Processing Record 105 of Set 1 |markova
# Processing Record 106 of Set 1 |bulalacao
# Processing Record 107 of Set 1 |bilma
# Processing Record 108 of Set 1 |gizo
# Processing Record 109 of Set 1 |talnakh
# Processing Record 110 of Set 1 |anahuac
# Processing Record 111 of Set 1 |conceicao da barra
# Processing Record 112 of Set 1 |cam ranh
# Processing Record 113 of Set 1 |bud
# Processing Record 114 of Set 1 |beian
# Processing Record 115 of Set 1 |zary
# Processing Record 116 of Set 1 |bom despacho
# Processing Record 117 of Set 1 |san quintin
# City not found. Skipping...
# Processing Record 118 of Set 1 |sentyabrskiy
# City not found. Skipping...
# Processing Record 119 of Set 1 |batticaloa
# Processing Record 120 of Set 1 |miandrivazo
# City not found. Skipping...
# Processing Record 121 of Set 1 |ndele
# City not found. Skipping...
# Processing Record 122 of Set 1 |havoysund
# Processing Record 123 of Set 1 |oranjemund
# Processing Record 124 of Set 1 |lamu
# Processing Record 125 of Set 1 |port blair
# Processing Record 126 of Set 1 |nouadhibou
# City not found. Skipping...
# Processing Record 127 of Set 1 |formoso do araguaia
# City not found. Skipping...
# Processing Record 128 of Set 1 |saldanha
# Processing Record 129 of Set 1 |kimbe
# Processing Record 130 of Set 1 |moron
# Processing Record 131 of Set 1 |thohoyandou
# City not found. Skipping...
# Processing Record 132 of Set 1 |kismayo
# City not found. Skipping...
# Processing Record 133 of Set 1 |jalu
# Processing Record 134 of Set 1 |russell
# Processing Record 135 of Set 1 |torbay
# Processing Record 136 of Set 1 |castro
# Processing Record 137 of Set 1 |vilyuysk
# Processing Record 138 of Set 1 |port lincoln
# City not found. Skipping...
# Processing Record 139 of Set 1 |toliary
# City not found. Skipping...
# Processing Record 140 of Set 1 |maslovare
# Processing Record 141 of Set 1 |pitimbu
# Processing Record 142 of Set 1 |xai-xai
# Processing Record 143 of Set 1 |bathsheba
# Processing Record 144 of Set 1 |clyde river
# Processing Record 145 of Set 1 |luderitz
# Processing Record 146 of Set 1 |bredasdorp
# Processing Record 147 of Set 1 |sitka
# Processing Record 148 of Set 1 |banjar
# Processing Record 149 of Set 1 |kangaatsiaq
# Processing Record 150 of Set 1 |hambantota
# Processing Record 151 of Set 1 |sovetskiy
# Processing Record 152 of Set 1 |pietermaritzburg
# Processing Record 153 of Set 1 |carauari
# Processing Record 154 of Set 1 |wakkanai
# Processing Record 155 of Set 1 |bayir
# Processing Record 156 of Set 1 |mataura
# Processing Record 157 of Set 1 |dikson
# Processing Record 158 of Set 1 |turukhansk
# City not found. Skipping...
# Processing Record 159 of Set 1 |aporawan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 160 of Set 1 |bur gabo
# City not found. Skipping...
# Processing Record 161 of Set 1 |cavalcante
# Processing Record 162 of Set 1 |labuan
# Processing Record 163 of Set 1 |rafsanjan
# Processing Record 164 of Set 1 |alenquer
# Processing Record 165 of Set 1 |lavrentiya
# Processing Record 166 of Set 1 |zhangye
# Processing Record 167 of Set 1 |aykhal
# Processing Record 168 of Set 1 |bonavista
# Processing Record 169 of Set 1 |bredy
# Processing Record 170 of Set 1 |cockburn town
# Processing Record 171 of Set 1 |laibin
# Processing Record 172 of Set 1 |portogruaro
# Processing Record 173 of Set 1 |mikhaylovka
# Processing Record 174 of Set 1 |san jeronimo
# Processing Record 175 of Set 1 |qaanaaq
# Processing Record 176 of Set 1 |east london
# Processing Record 177 of Set 1 |provideniya
# Processing Record 178 of Set 1 |aranos
# Processing Record 179 of Set 1 |falun
# Processing Record 180 of Set 1 |komsomolskiy
# Processing Record 181 of Set 1 |huilong
# Processing Record 182 of Set 1 |longyearbyen
# Processing Record 183 of Set 1 |avarua
# Processing Record 184 of Set 1 |port elizabeth
# Processing Record 185 of Set 1 |antalaha
# Processing Record 186 of Set 1 |doctor juan leon mallorquin
# Processing Record 187 of Set 1 |inhambane
# Processing Record 188 of Set 1 |ust-tsilma
# Processing Record 189 of Set 1 |batangafo
# City not found. Skipping...
# Processing Record 190 of Set 1 |muzquiz
# City not found. Skipping...
# Processing Record 191 of Set 1 |celestun
# City not found. Skipping...
# Processing Record 192 of Set 1 |qafsah
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 193 of Set 1 |oreanda
# City not found. Skipping...
# Processing Record 194 of Set 1 |imeni poliny osipenko
# Processing Record 195 of Set 1 |lata
# Processing Record 196 of Set 1 |saiki
# Processing Record 197 of Set 1 |westport
# Processing Record 198 of Set 1 |mehran
# Processing Record 199 of Set 1 |bergen
# Processing Record 200 of Set 1 |chuy
# Processing Record 201 of Set 1 |north bend
# Processing Record 202 of Set 1 |mehriz
# Processing Record 203 of Set 1 |rokupr
# Processing Record 204 of Set 1 |northam
# Processing Record 205 of Set 1 |chinsali
# Processing Record 206 of Set 1 |ostrovnoy
# Processing Record 207 of Set 1 |bluff
# Processing Record 208 of Set 1 |mamonovo
# Processing Record 209 of Set 1 |saint george
# Processing Record 210 of Set 1 |ust-barguzin
# Processing Record 211 of Set 1 |sur
# Processing Record 212 of Set 1 |thompson
# Processing Record 213 of Set 1 |brae
# Processing Record 214 of Set 1 |ancud
# Processing Record 215 of Set 1 |guerrero negro
# Processing Record 216 of Set 1 |tarko-sale
# Processing Record 217 of Set 1 |valenca
# Processing Record 218 of Set 1 |nikolayevsk-na-amure
# Processing Record 219 of Set 1 |makakilo city
# Processing Record 220 of Set 1 |rosarito
# Processing Record 221 of Set 1 |hasaki
# Processing Record 222 of Set 1 |touros
# Processing Record 223 of Set 1 |goderich
# Processing Record 224 of Set 1 |luanda
# Processing Record 225 of Set 1 |takoradi
# Processing Record 226 of Set 1 |cananeia
# Processing Record 227 of Set 1 |buba
# Processing Record 228 of Set 1 |georgetown
# Processing Record 229 of Set 1 |lasa
# Processing Record 230 of Set 1 |eureka
# Processing Record 231 of Set 1 |saint-francois
# Processing Record 232 of Set 1 |hamilton
# Processing Record 233 of Set 1 |anuradhapura
# Processing Record 234 of Set 1 |pingliang
# Processing Record 235 of Set 1 |coquimbo
# Processing Record 236 of Set 1 |punta arenas
# Processing Record 237 of Set 1 |atuona
# Processing Record 238 of Set 1 |khatanga
# Processing Record 239 of Set 1 |coahuayana
# Processing Record 240 of Set 1 |salalah
# Processing Record 241 of Set 1 |elizabeth city
# Processing Record 242 of Set 1 |chimbote
# Processing Record 243 of Set 1 |bom jesus
# Processing Record 244 of Set 1 |gobabis
# Processing Record 245 of Set 1 |kholtoson
# Processing Record 246 of Set 1 |kaoma
# Processing Record 247 of Set 1 |chokurdakh
# Processing Record 248 of Set 1 |comodoro rivadavia
# Processing Record 249 of Set 1 |san angelo
# Processing Record 250 of Set 1 |new norfolk
# Processing Record 251 of Set 1 |walvis bay
# Processing Record 252 of Set 1 |ouadda
# Processing Record 253 of Set 1 |sao joao da barra
# City not found. Skipping...
# Processing Record 254 of Set 1 |mys shmidta
# City not found. Skipping...
# Processing Record 255 of Set 1 |atherton
# Processing Record 256 of Set 1 |nekhayevskiy
# Processing Record 257 of Set 1 |mahebourg
# Processing Record 258 of Set 1 |bontang
# Processing Record 259 of Set 1 |vao
# Processing Record 260 of Set 1 |pisco
# Processing Record 261 of Set 1 |kushiro
# Processing Record 262 of Set 1 |kavaratti
# Processing Record 263 of Set 1 |puerto del rosario
# Processing Record 264 of Set 1 |cedar city
# Processing Record 265 of Set 1 |boguchany
# Processing Record 266 of Set 1 |vaini
# Processing Record 267 of Set 1 |brigantine
# Processing Record 268 of Set 1 |tessalit
# Processing Record 269 of Set 1 |grande prairie
# Processing Record 270 of Set 1 |hobart
# Processing Record 271 of Set 1 |artigas
# Processing Record 272 of Set 1 |nouakchott
# City not found. Skipping...
# Processing Record 273 of Set 1 |po
# City not found. Skipping...
# Processing Record 274 of Set 1 |labuhan
# Processing Record 275 of Set 1 |martin
# City not found. Skipping...
# Processing Record 276 of Set 1 |haibowan
# City not found. Skipping...
# Processing Record 277 of Set 1 |palmas bellas
# Processing Record 278 of Set 1 |huancavelica
# Processing Record 279 of Set 1 |mabaruma
# Processing Record 280 of Set 1 |denia
# Processing Record 281 of Set 1 |huarmey
# Processing Record 282 of Set 1 |iqaluit
# Processing Record 283 of Set 1 |carutapera
# Processing Record 284 of Set 1 |ayagoz
# Processing Record 285 of Set 1 |vangaindrano
# Processing Record 286 of Set 1 |fort nelson
# City not found. Skipping...
# Processing Record 287 of Set 1 |krasnoselkup
# City not found. Skipping...
# Processing Record 288 of Set 1 |kudahuvadhoo
# Processing Record 289 of Set 1 |charyshskoye
# Processing Record 290 of Set 1 |fershampenuaz
# Processing Record 291 of Set 1 |taltal
# Processing Record 292 of Set 1 |kavali
# Processing Record 293 of Set 1 |antofagasta
# Processing Record 294 of Set 1 |aklavik
# Processing Record 295 of Set 1 |sao filipe
# Processing Record 296 of Set 1 |pevek
# City not found. Skipping...
# Processing Record 297 of Set 1 |samusu
# City not found. Skipping...
# Processing Record 298 of Set 1 |tasiilaq
# City not found. Skipping...
# Processing Record 299 of Set 1 |novoilinsk
# City not found. Skipping...
# Processing Record 300 of Set 1 |tateyama
# City not found. Skipping...
# Processing Record 301 of Set 1 |tsihombe
# City not found. Skipping...
# Processing Record 302 of Set 1 |chicama
# Processing Record 303 of Set 1 |shadrinsk
# Processing Record 304 of Set 1 |apollonia
# Processing Record 305 of Set 1 |oum hadjer
# Processing Record 306 of Set 1 |xichang
# Processing Record 307 of Set 1 |dalvik
# Processing Record 308 of Set 1 |cartagena
# Processing Record 309 of Set 1 |dayong
# City not found. Skipping...
# Processing Record 310 of Set 1 |addis abeba
# City not found. Skipping...
# Processing Record 311 of Set 1 |preston
# Processing Record 312 of Set 1 |novyy urengoy
# Processing Record 313 of Set 1 |saint-philippe
# Processing Record 314 of Set 1 |kirakira
# Processing Record 315 of Set 1 |gorontalo
# City not found. Skipping...
# Processing Record 316 of Set 1 |karaul
# City not found. Skipping...
# Processing Record 317 of Set 1 |salinopolis
# Processing Record 318 of Set 1 |rio gallegos
# Processing Record 319 of Set 1 |tecoanapa
# Processing Record 320 of Set 1 |tadpatri
# Processing Record 321 of Set 1 |bainbridge
# Processing Record 322 of Set 1 |sayyan
# Processing Record 323 of Set 1 |burns lake
# City not found. Skipping...
# Processing Record 324 of Set 1 |taolanaro
# City not found. Skipping...
# Processing Record 325 of Set 1 |sorong
# Processing Record 326 of Set 1 |boralday
# Processing Record 327 of Set 1 |harper
# Processing Record 328 of Set 1 |benguela
# Processing Record 329 of Set 1 |beloha
# Processing Record 330 of Set 1 |fortuna
# Processing Record 331 of Set 1 |verkhnyaya inta
# Processing Record 332 of Set 1 |najran
# Processing Record 333 of Set 1 |deputatskiy
# Processing Record 334 of Set 1 |price
# City not found. Skipping...
# Processing Record 335 of Set 1 |khanion tou kokkini
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 336 of Set 1 |yomitan
# City not found. Skipping...
# Processing Record 337 of Set 1 |mar del plata
# Processing Record 338 of Set 1 |verkhnevilyuysk
# Processing Record 339 of Set 1 |qiqihar
# Processing Record 340 of Set 1 |humaita
# Processing Record 341 of Set 1 |leningradskiy
# Processing Record 342 of Set 1 |solok
# City not found. Skipping...
# Processing Record 343 of Set 1 |sindand
# City not found. Skipping...
# Processing Record 344 of Set 1 |paluan
# Processing Record 345 of Set 1 |karratha
# Processing Record 346 of Set 1 |ilulissat
# Processing Record 347 of Set 1 |esperance
# Processing Record 348 of Set 1 |shikarpur
# Processing Record 349 of Set 1 |acajutla
# Processing Record 350 of Set 1 |sivas
# Processing Record 351 of Set 1 |abu samrah
# Processing Record 352 of Set 1 |luebo
# Processing Record 353 of Set 1 |batemans bay
# Processing Record 354 of Set 1 |tiksi
# Processing Record 355 of Set 1 |buchanan
# Processing Record 356 of Set 1 |glushkovo
# Processing Record 357 of Set 1 |kano
# Processing Record 358 of Set 1 |salta
# Processing Record 359 of Set 1 |villa guerrero
# Processing Record 360 of Set 1 |mecca
# Processing Record 361 of Set 1 |kosovo polje
# Processing Record 362 of Set 1 |wanxian
# Processing Record 363 of Set 1 |ugoofaaru
# Processing Record 364 of Set 1 |camrose
# Processing Record 365 of Set 1 |hithadhoo
# Processing Record 366 of Set 1 |totma
# Processing Record 367 of Set 1 |vanimo
# Processing Record 368 of Set 1 |bundaberg
# City not found. Skipping...
# Processing Record 369 of Set 1 |saryshagan
# City not found. Skipping...
# Processing Record 370 of Set 1 |necochea
# Processing Record 371 of Set 1 |la romana
# Processing Record 372 of Set 1 |lima
# Processing Record 373 of Set 1 |butaritari
# Processing Record 374 of Set 1 |kirkland lake
# Processing Record 375 of Set 1 |tanout
# Processing Record 376 of Set 1 |taitung
# City not found. Skipping...
# Processing Record 377 of Set 1 |hihifo
# City not found. Skipping...
# Processing Record 378 of Set 1 |goure
# Processing Record 379 of Set 1 |airai
# Processing Record 380 of Set 1 |bakchar
# Processing Record 381 of Set 1 |shimoda
# City not found. Skipping...
# Processing Record 382 of Set 1 |santa cruz de rosales
# City not found. Skipping...
# Processing Record 383 of Set 1 |susanville
# City not found. Skipping...
# Processing Record 384 of Set 1 |attawapiskat
# City not found. Skipping...
# Processing Record 385 of Set 1 |lebu
# Processing Record 386 of Set 1 |nanortalik
# Processing Record 387 of Set 1 |portland
# Processing Record 388 of Set 1 |yumen
# Processing Record 389 of Set 1 |nome
# Processing Record 390 of Set 1 |geraldton
# Processing Record 391 of Set 1 |herat
# Processing Record 392 of Set 1 |pochutla
# Processing Record 393 of Set 1 |champerico
# Processing Record 394 of Set 1 |chumikan
# Processing Record 395 of Set 1 |mangrol
# Processing Record 396 of Set 1 |tuatapere
# Processing Record 397 of Set 1 |nadym
# Processing Record 398 of Set 1 |kapaa
# Processing Record 399 of Set 1 |busselton
# Processing Record 400 of Set 1 |codrington
# Processing Record 401 of Set 1 |charters towers
# Processing Record 402 of Set 1 |bridgend
# Processing Record 403 of Set 1 |lagoa
# Processing Record 404 of Set 1 |caraquet
# Processing Record 405 of Set 1 |ribeira grande
# Processing Record 406 of Set 1 |puga
# Processing Record 407 of Set 1 |sisimiut
# Processing Record 408 of Set 1 |praia da vitoria
# Processing Record 409 of Set 1 |lagos
# Processing Record 410 of Set 1 |obo
# Processing Record 411 of Set 1 |nishihara
# Processing Record 412 of Set 1 |nueva loja
# Processing Record 413 of Set 1 |kandrian
# Processing Record 414 of Set 1 |bowen
# Processing Record 415 of Set 1 |bako
# Processing Record 416 of Set 1 |beringovskiy
# Processing Record 417 of Set 1 |chiredzi
# Processing Record 418 of Set 1 |cuiluan
# Processing Record 419 of Set 1 |sambava
# Processing Record 420 of Set 1 |cherskiy
# Processing Record 421 of Set 1 |biak
# City not found. Skipping...
# Processing Record 422 of Set 1 |halalo
# City not found. Skipping...
# Processing Record 423 of Set 1 |rikitea
# Processing Record 424 of Set 1 |jacksonville beach
# City not found. Skipping...
# Processing Record 425 of Set 1 |marcona
# City not found. Skipping...
# Processing Record 426 of Set 1 |banfora
# Processing Record 427 of Set 1 |terrace bay
# Processing Record 428 of Set 1 |beyneu
# Processing Record 429 of Set 1 |robertsport
# Processing Record 430 of Set 1 |port hedland
# Processing Record 431 of Set 1 |arraial do cabo
# Processing Record 432 of Set 1 |la ronge
# Processing Record 433 of Set 1 |haines junction
# Processing Record 434 of Set 1 |nikolskoye
# Processing Record 435 of Set 1 |coihaique
# Processing Record 436 of Set 1 |berezovyy
# Processing Record 437 of Set 1 |egvekinot
# Processing Record 438 of Set 1 |hermanus
# Processing Record 439 of Set 1 |west bay
# Processing Record 440 of Set 1 |alcantara
# Processing Record 441 of Set 1 |rafraf
# Processing Record 442 of Set 1 |luang prabang
# Processing Record 443 of Set 1 |lyantonde
# Processing Record 444 of Set 1 |nedjo
# Processing Record 445 of Set 1 |ringkobing
# Processing Record 446 of Set 1 |hami
# Processing Record 447 of Set 1 |namatanai
# City not found. Skipping...
# Processing Record 448 of Set 1 |artyk
# City not found. Skipping...
# Processing Record 449 of Set 1 |dunedin
# Processing Record 450 of Set 1 |gelibolu
# City not found. Skipping...
# Processing Record 451 of Set 1 |umm ruwabah
# City not found. Skipping...
# Processing Record 452 of Set 1 |barrow
# Processing Record 453 of Set 1 |houston
# Processing Record 454 of Set 1 |ryotsu
# City not found. Skipping...
# Processing Record 455 of Set 1 |malwan
# City not found. Skipping...
# Processing Record 456 of Set 1 |jamestown
# Processing Record 457 of Set 1 |margate
# City not found. Skipping...
# Processing Record 458 of Set 1 |illoqqortoormiut
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 459 of Set 1 |utiroa
# City not found. Skipping...
# Processing Record 460 of Set 1 |san patricio
# Processing Record 461 of Set 1 |shobara
# Processing Record 462 of Set 1 |mareeba
# Processing Record 463 of Set 1 |surt
# Processing Record 464 of Set 1 |kraskino
# Processing Record 465 of Set 1 |kruisfontein
# Processing Record 466 of Set 1 |coxim
# Processing Record 467 of Set 1 |bambous virieux
# Processing Record 468 of Set 1 |gat
# Processing Record 469 of Set 1 |guanay
# Processing Record 470 of Set 1 |merauke
# Processing Record 471 of Set 1 |dingle
# Processing Record 472 of Set 1 |putyatino
# Processing Record 473 of Set 1 |severo-kurilsk
# Processing Record 474 of Set 1 |hilo
# Processing Record 475 of Set 1 |souillac
# Processing Record 476 of Set 1 |norman wells
# Processing Record 477 of Set 1 |forssa
# Processing Record 478 of Set 1 |osmena
# Processing Record 479 of Set 1 |dese
# Processing Record 480 of Set 1 |xapuri
# Processing Record 481 of Set 1 |puerto ayora
# Processing Record 482 of Set 1 |panshi
# Processing Record 483 of Set 1 |kaitangata
# Processing Record 484 of Set 1 |kaohsiung
# City not found. Skipping...
# Processing Record 485 of Set 1 |korla
# City not found. Skipping...
# Processing Record 486 of Set 1 |sochaczew
# City not found. Skipping...
# Processing Record 487 of Set 1 |longlac
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 488 of Set 1 |bokspits
# City not found. Skipping...
# Processing Record 489 of Set 1 |darhan
# Processing Record 490 of Set 1 |albany
# Processing Record 491 of Set 1 |zanesville
# City not found. Skipping...
# Processing Record 492 of Set 1 |lolua
# City not found. Skipping...
# Processing Record 493 of Set 1 |sevsk
# Processing Record 494 of Set 1 |wanning
# Processing Record 495 of Set 1 |middle island
# Processing Record 496 of Set 1 |stephenville
# Processing Record 497 of Set 1 |kuusamo
# Processing Record 498 of Set 1 |riyadh
# Processing Record 499 of Set 1 |sola
# Processing Record 500 of Set 1 |ahipara

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
w_df = pd.DataFrame(citi_data)
w_df.to_csv(output_data_file, index_label = "citi_id")

# %%
w_df.count()
# Out:
# City          895
# Cloudiness    895
# Country       895
# Date          895
# Humidity      895
# Lat           895
# Lng           895
# Max Temp      895
# Wind Speed    895
# dtype: int64

# %%
w_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     wanning           0      AT  1566944693        77  48.64   13.53
# 1   lyantonde           0      UG  1566944693        74  -0.41   31.15
# 2      ankang          69      CN  1566944693        95  32.73  108.99
# 3  nikolskoye           0      RU  1566944545        82  59.70   30.79
# 4     atambua          32      ID  1566944693        73  -9.11  124.89
#
#    Max Temp  Wind Speed
# 0    294.15        1.50
# 1    292.90        1.49
# 2    290.00        0.80
# 3    287.15        0.82
# 4    297.10        6.22

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(w_df["Lat"],w_df["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(w_df["Lat"],w_df["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)
plt.savefig("fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(w_df["Lat"],w_df["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)
plt.savefig("fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(w_df["Lat"],w_df["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid(True)
plt.savefig("fig4.png")
plt.show()
